# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import os
import numpy as np

# %% [markdown]
# ### Import Files

# %%
WHITE_LC = pd.read_csv("C:\\Users\\Owner\\OneDrive - UTS\\Chapter 4\\Chapter 4 Experimental Data\\Organised Data\\White_LC_Average_Parameters.csv")
RGB_LC = pd.read_csv("C:\\Users\\Owner\\OneDrive - UTS\\Chapter 4\\Chapter 4 Experimental Data\\Organised Data\\RGB_LC_Average_Parameters.csv")
RB_LC = pd.read_csv("C:\\Users\\Owner\\OneDrive - UTS\\Chapter 4\\Chapter 4 Experimental Data\\Organised Data\\RB_LC_Average_Parameters.csv")

# %% [markdown]
# ### Specify Measurement Ranges

# %%
pre_dawn = list(range(0, 25))
dawn = list(range(26, 51))
midday = list(range(52, 77))
afternoon = list(range(78, 103))
night = list(range(104, 129))

# %% [markdown]
# ### Specify Subject Parameters

# %%
x_axis = "PAR"
y_axis = "ETR"
y_error = "ETRStDev"

# %% [markdown]
# ### Plot Graphs

# %%
plt.errorbar(x=[float(x) for x in WHITE_LC[x_axis][pre_dawn].dropna().unique()], 
             y=[float(x) for x in WHITE_LC[y_axis][pre_dawn].dropna()],
             yerr=[float(x) for x in WHITE_LC[y_error][pre_dawn].dropna()])
plt.errorbar(x=[float(x) for x in RGB_LC[x_axis][pre_dawn].dropna().unique()], 
             y=[float(x) for x in RGB_LC[y_axis][pre_dawn].dropna()],
             yerr=[float(x) for x in RGB_LC[y_error][pre_dawn].dropna()])
plt.errorbar(x=[float(x) for x in RB_LC[x_axis][pre_dawn].dropna().unique()], 
             y=[float(x) for x in RB_LC[y_axis][pre_dawn].dropna()],
             yerr=[float(x) for x in RB_LC[y_error][pre_dawn].dropna()])
plt.title("Pre-Dawn")
# Out:
# Text(0.5, 1.0, 'Pre-Dawn')

# %%
plt.errorbar(x=[float(x) for x in WHITE_LC[x_axis][dawn].dropna().unique()], 
             y=[float(x) for x in WHITE_LC[y_axis][dawn].dropna()],
             yerr=[float(x) for x in WHITE_LC[y_error][dawn].dropna()])
plt.errorbar(x=[float(x) for x in RGB_LC[x_axis][dawn].dropna().unique()], 
             y=[float(x) for x in RGB_LC[y_axis][dawn].dropna()],
             yerr=[float(x) for x in RGB_LC[y_error][dawn].dropna()])
plt.errorbar(x=[float(x) for x in RB_LC[x_axis][dawn].dropna().unique()], 
             y=[float(x) for x in RB_LC[y_axis][dawn].dropna()],
             yerr=[float(x) for x in RB_LC[y_error][dawn].dropna()])
plt.title("Dawn")
# Out:
# Text(0.5, 1.0, 'Dawn')

# %%
plt.errorbar(x=[float(x) for x in WHITE_LC[x_axis][midday].dropna().unique()], 
             y=[float(x) for x in WHITE_LC[y_axis][midday].dropna()],
             yerr=[float(x) for x in WHITE_LC[y_error][midday].dropna()])
plt.errorbar(x=[float(x) for x in RGB_LC[x_axis][midday].dropna().unique()], 
             y=[float(x) for x in RGB_LC[y_axis][midday].dropna()],
             yerr=[float(x) for x in RGB_LC[y_error][midday].dropna()])
plt.errorbar(x=[float(x) for x in RB_LC[x_axis][midday].dropna().unique()], 
             y=[float(x) for x in RB_LC[y_axis][midday].dropna()],
             yerr=[float(x) for x in RB_LC[y_error][midday].dropna()])
plt.title("Midday")
# Out:
# Text(0.5, 1.0, 'Midday')

# %%
plt.errorbar(x=[float(x) for x in WHITE_LC[x_axis][afternoon].dropna().unique()], 
             y=[float(x) for x in WHITE_LC[y_axis][afternoon].dropna()],
             yerr=[float(x) for x in WHITE_LC[y_error][afternoon].dropna()])
plt.errorbar(x=[float(x) for x in RGB_LC[x_axis][afternoon].dropna().unique()], 
             y=[float(x) for x in RGB_LC[y_axis][afternoon].dropna()],
             yerr=[float(x) for x in RGB_LC[y_error][afternoon].dropna()])
plt.errorbar(x=[float(x) for x in RB_LC[x_axis][afternoon].dropna().unique()], 
             y=[float(x) for x in RB_LC[y_axis][afternoon].dropna()],
             yerr=[float(x) for x in RB_LC[y_error][afternoon].dropna()])
plt.title("Afternoon")
# Out:
# Text(0.5, 1.0, 'Afternoon')

# %%
plt.errorbar(x=[float(x) for x in WHITE_LC[x_axis][night].dropna().unique()], 
             y=[float(x) for x in WHITE_LC[y_axis][night].dropna()],
             yerr=[float(x) for x in WHITE_LC[y_error][night].dropna()])
plt.errorbar(x=[float(x) for x in RGB_LC[x_axis][night].dropna().unique()], 
             y=[float(x) for x in RGB_LC[y_axis][night].dropna()],
             yerr=[float(x) for x in RGB_LC[y_error][night].dropna()])
plt.errorbar(x=[float(x) for x in RB_LC[x_axis][night].dropna().unique()], 
             y=[float(x) for x in RB_LC[y_axis][night].dropna()],
             yerr=[float(x) for x in RB_LC[y_error][night].dropna()])
plt.title("Night")
# Out:
# Text(0.5, 1.0, 'Night')
